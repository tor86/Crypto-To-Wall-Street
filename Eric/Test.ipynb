# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
# %matplotlib inline
from sklearn import preprocessing
from collections import deque
# Dependencies and Setup
import matplotlib.pyplot as plt
import os
import numpy as np
import random
from sklearn.cluster import KMeans
import hvplot
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import session
from sqlalchemy import create_engine, func

# %%
# Out:
#   File "C:\Users\Crabby\AppData\Local\Temp\ipykernel_27160\2147177952.py", line 1
#     mongodb://localhost:27017
#              ^
# SyntaxError: invalid syntax

# %%
#Test

# %%
import numpy as np
import pandas as pd
import numba as N
from numba import jit, cuda
from pathlib import Path
from collections import Counter

# %%
#  Import and read the data
bitcoin_df = pd.read_csv("bitcoin_df.csv")
df=bitcoin_df
bitcoin_df.head()
# Out:
#          Date  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  12/31/2011  4.39  4.39  4.39   4.39      0.455581           2.000000
# 1  12/31/2011  4.39  4.39  4.39   4.39     48.000000         210.720000
# 2  12/31/2011  4.50  4.57  4.50   4.57     37.862297         171.380337
# 3  12/31/2011  4.58  4.58  4.58   4.58      9.000000          41.220000
# 4    1/1/2012  4.58  4.58  4.58   4.58      1.502000           6.879160
#
#    Weighted_Price
# 0        4.390000
# 1        4.390000
# 2        4.526411
# 3        4.580000
# 4        4.580000

# %%
columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume_(BTC)', 'Volume_(currency)']
target= ['Weighted_Price']

# %%
# Create our features
X = pd.get_dummies(df.drop(columns='Weighted_Price'))

# Create our target
y = df['Weighted_Price']

# %%
X.describe()
# Out:
#                Open          High           Low         Close  Volume_(BTC)  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.501080e+02  3.504233e+02  3.497688e+02  3.501040e+02  1.416257e+01
# std    2.297427e+02  2.300355e+02  2.294339e+02  2.297464e+02  4.717831e+01
# min    3.800000e+00  3.800000e+00  3.800000e+00  3.800000e+00  0.000000e+00
# 25%    2.000000e+02  2.001950e+02  1.999900e+02  2.000000e+02  5.297234e-01
# 50%    2.767300e+02  2.768000e+02  2.766100e+02  2.767200e+02  2.243470e+00
# 75%    4.999700e+02  5.000100e+02  4.993600e+02  4.999900e+02  9.908941e+00
# max    1.163000e+03  1.163000e+03  1.162990e+03  1.163000e+03  5.853852e+03
#
#        Volume_(Currency)  Date_1/1/2012  Date_1/1/2013  Date_1/1/2014  \
# count       1.048575e+06   1.048575e+06   1.048575e+06   1.048575e+06
# mean        4.978490e+03   2.861026e-06   4.863744e-05   1.032830e-03
# std         1.982492e+04   1.691455e-03   6.973888e-03   3.212109e-02
# min         0.000000e+00   0.000000e+00   0.000000e+00   0.000000e+00
# 25%         1.200229e+02   0.000000e+00   0.000000e+00   0.000000e+00
# 50%         5.682333e+02   0.000000e+00   0.000000e+00   0.000000e+00
# 75%         2.740941e+03   0.000000e+00   0.000000e+00   0.000000e+00
# max         1.865889e+06   1.000000e+00   1.000000e+00   1.000000e+00
#
#        Date_1/1/2015  ...  Date_9/7/2014  Date_9/7/2015  Date_9/8/2012  \
# count   1.048575e+06  ...   1.048575e+06   1.048575e+06   1.048575e+06
# mean    6.790168e-04  ...   8.869180e-04   9.164819e-04   5.912786e-05
# std     2.604911e-02  ...   2.976797e-02   3.025959e-02   7.689241e-03
# min     0.000000e+00  ...   0.000000e+00   0.000000e+00   0.000000e+00
# 25%     0.000000e+00  ...   0.000000e+00   0.000000e+00   0.000000e+00
# 50%     0.000000e+00  ...   0.000000e+00   0.000000e+00   0.000000e+00
# 75%     0.000000e+00  ...   0.000000e+00   0.000000e+00   0.000000e+00
# max     1.000000e+00  ...   1.000000e+00   1.000000e+00   1.000000e+00
#
#        Date_9/8/2013  Date_9/8/2014  Date_9/8/2015  Date_9/9/2012  \
# count   1.048575e+06   1.048575e+06   1.048575e+06   1.048575e+06
# mean    5.826956e-04   1.146318e-03   1.051904e-03   6.008154e-05
# std     2.413207e-02   3.383792e-02   3.241602e-02   7.750999e-03
# min     0.000000e+00   0.000000e+00   0.000000e+00   0.000000e+00
# 25%     0.000000e+00   0.000000e+00   0.000000e+00   0.000000e+00
# 50%     0.000000e+00   0.000000e+00   0.000000e+00   0.000000e+00
# 75%     0.000000e+00   0.000000e+00   0.000000e+00   0.000000e+00
# max     1.000000e+00   1.000000e+00   1.000000e+00   1.000000e+00
#
#        Date_9/9/2013  Date_9/9/2014  Date_9/9/2015
# count   1.048575e+06   1.048575e+06   1.048575e+06
# mean    8.935937e-04   1.115800e-03   1.047135e-03
# std     2.987969e-02   3.338497e-02   3.234254e-02
# min     0.000000e+00   0.000000e+00   0.000000e+00
# 25%     0.000000e+00   0.000000e+00   0.000000e+00
# 50%     0.000000e+00   0.000000e+00   0.000000e+00
# 75%     0.000000e+00   0.000000e+00   0.000000e+00
# max     1.000000e+00   1.000000e+00   1.000000e+00
#
# [8 rows x 1405 columns]

# %%
y.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0            4.390000
# 1            4.390000
# 2            4.526411
# 3            4.580000
# 4            4.580000
#               ...
# 1048570    315.301729
# 1048571    315.431722
# 1048572    315.868414
# 1048573    315.352852
# 1048574    315.809064
# Name: Weighted_Price, Length: 1048575, dtype: float64>

# %%
from skmultilearn.model_selection import iterative_train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=42)
X_train.shape
# Out:
# (786431, 1405)

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)
Counter(y_resampled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27160\1846786057.py in <module>
#       1 from imblearn.over_sampling import RandomOverSampler
#       2 ros = RandomOverSampler(random_state=1)
# ----> 3 X_resampled, y_resampled = ros.fit_resample(X_train, y_train)
#       4 Counter(y_resampled)
#
# c:\Users\Crabby\anaconda3\envs\mlenv\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      73             The corresponding label of `X_resampled`.
#      74         """
# ---> 75         check_classification_targets(y)
#      76         arrays_transformer = ArraysTransformer(X, y)
#      77         X, y, binarize_y = self._check_X_y(X, y)
#
# c:\Users\Crabby\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     195         "multilabel-sequences",
#     196     ]:
# --> 197         raise ValueError("Unknown label type: %r" % y_type)
#     198
#     199
#
# ValueError: Unknown label type: 'continuous'

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6852\1760535629.py in <module>
#       1 from sklearn.linear_model import LogisticRegression
#       2 model = LogisticRegression(solver='lbfgs', random_state=1)
# ----> 3 model.fit(X_resampled, y_resampled)
#
# NameError: name 'X_resampled' is not defined

# %%
from sklearn.metrics import balanced_accuracy_score
y_pred = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

classifier = LogisticRegression(solver='lbfgs', max_iter=200, random_state=1)

classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))

 Counter(y_train)
classifier.fit(X_train, y_train)
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

# %%
moving_bit_df = []

# %%
# def bitcoin():
    
#     moving_bit_df = []   

#     moving_bit_df['Label']= label

#     for price in bitcoin_df["Weighted_Price"]:
#         if price > 0 :
#             label.append(label)
#         # 4b: Add the existing county to the list of counties.
#            # county_names.append(county_name)


if scale:
         column_scaler = {}
         # scale the data (prices) from 0 to 1
         for column in feature_columns:            scaler = preprocessing.MinMaxScaler()
           bitcoin_df[column] = scaler.fit_transform(np.expand_dims(bitcoin_df[column].values, axis=1))
             column_scaler[column] = scaler
          add the MinMaxScaler instances to the result returned
         result["column_scaler"] = column_scaler
     add the target column (label) by shifting by `lookup_step`
 bitcoin_df['Label'] = bitcoin_df["Weighted_Price"].shift(-lookup_step)

# print(moving_bit_df)
